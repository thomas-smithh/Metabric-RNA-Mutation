# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras import models, layers
from keras.utils import to_categorical
from keras import regularizers
from xgboost import XGBClassifier
from importlib import reload
import model_utils as mu
from sklearn.cluster import DBSCAN, KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import SCORERS
from sklearn.ensemble import RandomForestClassifier
import scikitplot as skplot
pd.set_option("display.max_rows", 1000)
# Out:
# C:\Users\tjs_1\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %% [markdown]
# #### Things I can build with the data
#
# - Data Cleaning
#     * For numerical data - examine variables with highest correlation with the missing data - build regression model and make prediction and fill in missing data with predicted value
#     * For categorical data - Build a simple classifier and fill in any missing data
# - Exploratory data analysis:
#     * Draw standard correlations, heatmaps - that sort of thing
#     * Utilise clustering to create groups of people - stratified by age and explore death rate for various sub-groupings
#     * Itilise clustering to examine if various groups are more responsive to radio/chemo therapy
# - Classification Model Building:
#     * Predict overall_survival
#     * Tune models utilising grid search CV etc etc to prove ML ability - properly assess models by use of confusion matrices/ROC curves etc.
#     * Segment population
#     * After fitting a model, segment the test dataset by probability and observe and interpret correlations
#     * Build a model which looks to predict the best course of treatment for an individual given their proteome -
# - Regression Model Building
#     * Predict overall_survival months
# - Explore patients who have undergone chemo and their cellularity post chemo - attempt to build an idea of proteome of patient most susceptible to chemo

# %% [markdown]
# ### List of Important Caveats to mention

# %% [markdown]
# - "Death from Cancer" metric -> "died of other causes" - we do not know if these other causes were related to the cancer
# - When building model purely from proteomic data, there may be other factors influencing the outcome, it's impossible to normalize/control for this.

# %% [markdown]
# ### Data Cleaning & Preprocessing

# %%
def convert_death_from_cancer(data):
    if data == 'Living' or data == 'Died of Other Causes':
        return 0
    else:
        return 1

# %%
data = pd.read_csv('Data/METABRIC_RNA_Mutation.csv')
protein_columns = list(data.select_dtypes(exclude=['object']).columns)[14:]
data.drop(['cancer_type', 'cohort'], axis=1, inplace=True)
data.set_index('patient_id', inplace=True)
nulls = data.isna().sum()[data.isna().sum() > 0]
data = data.infer_objects()
mutation_cols = [x for x in data.columns if 'mut' in x and x != 'mutation_count']
data = pd.concat([data.drop(mutation_cols, 1), pd.get_dummies(data[mutation_cols])], axis=1)
data = data.loc[:,~data.columns.duplicated()]
data.death_from_cancer = data.death_from_cancer.apply(convert_death_from_cancer)
# Out:
# C:\Users\tjs_1\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (678,688,690,692) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Building Model to Predict Death From Cancer
#
# - Model building to predict death from cancer based only on the proteomic data. I will assess the model and establish a picture of the most important features in the dataset.

# %%
def preprocess_data(data):
    columns_to_impute = ['cancer_type_detailed', 'neoplasm_histologic_grade', 'tumor_other_histologic_subtype', 'primary_tumor_laterality', 'oncotree_code', '3-gene_classifier_subtype', 'tumor_stage']
    data, metrics = mu.data_imputer(data, columns_to_impute)
    data = pd.concat([data.select_dtypes(exclude=['object']), pd.get_dummies(data.select_dtypes('object'))], axis=1)
    data.fillna(-1, inplace=True)
    return data

# %%
protein_columns = data.columns[29:]
X, y = data[protein_columns], data.death_from_cancer
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.15)
# X_train, X_test = preprocess_data(X_train), preprocess_data(X_test)
xgb_clf = XGBClassifier(max_depth=5)
xgb_clf.fit(X_train, y_train)

# %%
xgb_metrics = mu.assess_model(xgb_clf, X_test, y_test, features=X.columns, threshold=0.232049)

# %%
mu.plot_roc_curve['']

# %% [markdown]
# ### Building Model to predict effectiveness of chemo

# %%
reload(mu)
# Out:
# <module 'model_utils' from 'C:\\Users\\tjs_1\\OneDrive\\Documents\\Git repos\\Metabric-RNA-Mutation\\model_utils.py'>

# %%
def get_cellularity(data):
    if data == 'Low':
        return 0
    elif data == 'Moderate':
        return 1
    else:
        return 2

# %%
def preprocess_data(data):
    columns_to_impute = ['cancer_type_detailed', 'neoplasm_histologic_grade', 'tumor_other_histologic_subtype', 'primary_tumor_laterality', 'oncotree_code', '3-gene_classifier_subtype', 'tumor_stage']
    data, metrics = mu.data_imputer(data, columns_to_impute)
    data = pd.concat([data.select_dtypes(exclude=['object']), pd.get_dummies(data.select_dtypes('object'))], axis=1)
    data.fillna(-1, inplace=True)
    return data

# %%
data.cellularity = data.cellularity.apply(get_cellularity)

# %%
chemo_data = data[data.chemotherapy == 1].copy()
chemo_data.drop(['overall_survival', 'overall_survival_months'], 1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(chemo_data.drop('cellularity', 1), chemo_data.cellularity, stratify=chemo_data.cellularity, test_size=0.1)
X_train, X_test = preprocess_data(X_train), preprocess_data(X_test)
xgb_clf = XGBClassifier(max_depth=5)
xgb_clf.fit(X_train, y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# C:\Users\tjs_1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\tjs_1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\tjs_1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-310-3c74f1b2b7d4> in <module>
#       2 chemo_data.drop(['overall_survival', 'overall_survival_months'], 1, inplace=True)
#       3 X_train, X_test, y_train, y_test = train_test_split(chemo_data.drop('cellularity', 1), chemo_data.cellularity, stratify=chemo_data.cellularity, test_size=0.1)
# ----> 4 X_train, X_test = preprocess_data(X_train), preprocess_data(X_test)
#       5 xgb_clf = XGBClassifier(max_depth=5)
#       6 xgb_clf.fit(X_train, y_train)
#
# <ipython-input-309-b844f1f152be> in preprocess_data(data)
#       1 def preprocess_data(data):
#       2     columns_to_impute = ['cancer_type_detailed', 'neoplasm_histologic_grade', 'tumor_other_histologic_subtype', 'primary_tumor_laterality', 'oncotree_code', '3-gene_classifier_subtype', 'tumor_stage']
# ----> 3     data, metrics = mu.data_imputer(data, columns_to_impute)
#       4     data = pd.concat([data.select_dtypes(exclude=['object']), pd.get_dummies(data.select_dtypes('object'))], axis=1)
#       5     data.fillna(-1, inplace=True)
#
# ~\OneDrive\Documents\Git repos\Metabric-RNA-Mutation\model_utils.py in data_imputer(data, columns)
#      92         metrics.columns = metric_names
#      93         model_metrics = pd.concat([model_metrics, metrics])
# ---> 94         y_null = encoder.inverse_transform(dtc.predict(X_null))
#      95         data.loc[data[col].isna(), col] = y_null
#      96     model_metrics.index = target_cols
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     428         """
#     429         check_is_fitted(self, 'tree_')
# --> 430         X = self._validate_X_predict(X, check_input)
#     431         proba = self.tree_.predict(X)
#     432         n_samples = X.shape[0]
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     389         """Validate X whenever one tries to predict, apply, predict_proba"""
#     390         if check_input:
# --> 391             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     392             if issparse(X) and (X.indices.dtype != np.intc or
#     393                                 X.indptr.dtype != np.intc):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     548                              " minimum of %d is required%s."
#     549                              % (n_samples, array.shape, ensure_min_samples,
# --> 550                                 context))
#     551
#     552     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 8455)) while a minimum of 1 is required.

# %%
chemo_data.loc[:, chemo_data.isna().any()]
# Out:
#            type_of_breast_surgery                       cancer_type_detailed  \
# patient_id
# 5                      MASTECTOMY           Breast Invasive Ductal Carcinoma
# 6                      MASTECTOMY  Breast Mixed Ductal and Lobular Carcinoma
# 8                      MASTECTOMY  Breast Mixed Ductal and Lobular Carcinoma
# 14              BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 45                     MASTECTOMY           Breast Invasive Ductal Carcinoma
# 48              BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 50              BREAST CONSERVING  Breast Mixed Ductal and Lobular Carcinoma
# 60              BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 62                     MASTECTOMY           Breast Invasive Ductal Carcinoma
# 79                     MASTECTOMY           Breast Invasive Ductal Carcinoma
# 100                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 102                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 106                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 108             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 113                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 115                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 116                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 124             BREAST CONSERVING  Breast Mixed Ductal and Lobular Carcinoma
# 127             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 129                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 131                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 133             BREAST CONSERVING  Breast Mixed Ductal and Lobular Carcinoma
# 164                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 165                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 166             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 172                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 174             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 176                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 179                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 188                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 189                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 194                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 197                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 198                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 201                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 202                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 203                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 206                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 214             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 218             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 222             BREAST CONSERVING          Breast Invasive Lobular Carcinoma
# 223                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 235             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 236                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 238                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 243             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 248                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 257             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 259                           NaN           Breast Invasive Ductal Carcinoma
# 269                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 278                           NaN           Breast Invasive Ductal Carcinoma
# 282             BREAST CONSERVING  Breast Mixed Ductal and Lobular Carcinoma
# 288                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 291             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 294                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 305                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 307             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 315                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 321                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 324                           NaN           Breast Invasive Ductal Carcinoma
# 345                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 352                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 358                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 362                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 364                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 368                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 369                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 370                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 372             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 378                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 379             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 381             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 382             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 385             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 388                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 389                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 391             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 392                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 393                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 396             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 399                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 400             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 401             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 406                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 411                    MASTECTOMY  Breast Mixed Ductal and Lobular Carcinoma
# 413             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 420             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 424                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 426                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 434                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 438                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 440             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 445             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 446                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 449                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 453                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 458                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 464                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 466                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 467             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 468                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 469                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 474                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 476                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 479                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 481             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 482             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 483                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 484             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 485                    MASTECTOMY  Breast Mixed Ductal and Lobular Carcinoma
# 486                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 489                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 494                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 495                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 496                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 500             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 501             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 502             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 506             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 514             BREAST CONSERVING                                        NaN
# 516             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 519                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 524             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 525             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 528                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 529                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 531                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 532                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 534                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 537             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 538                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 541                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 542                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 544                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 552                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 559                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 569                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 575                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 578                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 580                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 587                    MASTECTOMY  Breast Mixed Ductal and Lobular Carcinoma
# 590                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 593                    MASTECTOMY          Breast Invasive Lobular Carcinoma
# 597                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 599             BREAST CONSERVING           Breast Invasive Ductal Carcinoma
# 601                    MASTECTOMY           Breast Invasive Ductal Carcinoma
# 607                           NaN           Breast Invasive Ductal Carcinoma
# 609                    MASTECTOMY           Breast Invasive Ductal Carcinoma
#
# 5633                       ER-/HER2-       30.00          3.0
# 5651                       ER-/HER2-       26.00          2.0
# 6055                       ER-/HER2-       25.00          NaN
# 6058                       ER-/HER2-       18.00          NaN
# 6059           ER+/HER2- High Prolif       48.00          NaN
# 6063                           HER2+      120.00          NaN
# 6082            ER+/HER2- Low Prolif       70.00          NaN
# 6085                       ER-/HER2-       26.00          NaN
# 6098                             NaN       80.00          NaN
# 6100                             NaN       30.00          3.0
# 6113                           HER2+       20.00          2.0
# 6114           ER+/HER2- High Prolif       28.00          NaN
# 6122                       ER-/HER2-       35.00          NaN
# 6160                           HER2+         NaN          NaN
# 6184           ER+/HER2- High Prolif       50.00          NaN
# 6194            ER+/HER2- Low Prolif       25.00          2.0
# 6217           ER+/HER2- High Prolif         NaN          NaN
# 6223                       ER-/HER2-       20.00          2.0
# 6224                       ER-/HER2-       10.00          2.0
# 6239           ER+/HER2- High Prolif       20.00          2.0
# 6242                       ER-/HER2-       55.00          NaN
# 6246                           HER2+       30.00          NaN
# 6248                       ER-/HER2-       55.00          NaN
# 6251                             NaN       30.00          2.0
# 6272                             NaN         NaN          NaN
# 6273                             NaN       16.00          NaN
# 6280                             NaN       44.00          NaN
# 6287                             NaN       35.00          NaN
# 6305                       ER-/HER2-       30.00          NaN
# 6319            ER+/HER2- Low Prolif       62.00          NaN
# 6330                           HER2+       20.00          NaN
# 6336                       ER-/HER2-       25.00          NaN
# 6337                           HER2+       55.00          NaN
# 6363                           HER2+       25.00          NaN
# 7007                       ER-/HER2-       17.00          NaN
# 7009                       ER-/HER2-       27.00          NaN
# 7012                       ER-/HER2-       20.00          NaN
# 7017                       ER-/HER2-       27.00          NaN
# 7018           ER+/HER2- High Prolif       40.00          NaN
# 7020                           HER2+       27.00          NaN
# 7023                       ER-/HER2-       40.00          NaN
# 7027                           HER2+       15.00          NaN
# 7031                             NaN       40.00          NaN
# 7035                           HER2+       50.00          NaN
# 7036                       ER-/HER2-       18.00          NaN
# 7038                       ER-/HER2-       22.00          NaN
# 7050           ER+/HER2- High Prolif       22.50          NaN
# 7054                       ER-/HER2-       12.80          NaN
# 7057            ER+/HER2- Low Prolif       22.00          NaN
# 7059                           HER2+       24.00          NaN
# 7066            ER+/HER2- Low Prolif       18.50          NaN
# 7073                           HER2+       20.00          NaN
# 7082                           HER2+       20.00          NaN
# 7083           ER+/HER2- High Prolif       26.00          NaN
# 7087                             NaN       14.00          NaN
# 7089                       ER-/HER2-       18.00          NaN
# 7090                       ER-/HER2-       17.00          NaN
# 7093            ER+/HER2- Low Prolif       16.90          NaN
# 7097           ER+/HER2- High Prolif       40.30          NaN
# 7112           ER+/HER2- High Prolif       40.00          NaN
# 7119                       ER-/HER2-       23.00          NaN
# 7121                       ER-/HER2-       38.00          NaN
# 7135                           HER2+       26.00          NaN
# 7145                       ER-/HER2-       25.00          NaN
# 7155                       ER-/HER2-       17.20          NaN
# 7158                       ER-/HER2-       29.00          NaN
# 7159                             NaN       34.00          NaN
# 7163            ER+/HER2- Low Prolif       30.00          NaN
# 7165                       ER-/HER2-      182.00          NaN
# 7182           ER+/HER2- High Prolif       27.00          NaN
# 7187                           HER2+        2.30          NaN
# 7189                             NaN       21.00          NaN
# 7194           ER+/HER2- High Prolif       21.50          NaN
# 7205                       ER-/HER2-       25.00          NaN
# 7207                       ER-/HER2-       30.00          NaN
# 7208                       ER-/HER2-       31.10          NaN
# 7225                             NaN       38.00          NaN
# 7226           ER+/HER2- High Prolif       17.60          NaN
# 7256                           HER2+       40.00          NaN
# 7258                             NaN       30.00          NaN
# 7260                           HER2+       24.15          NaN
# 7267                             NaN       20.50          NaN
# 7269                       ER-/HER2-       25.00          NaN
# 7270                       ER-/HER2-       16.00          NaN
# 7273                           HER2+       20.00          NaN
# 7275                           HER2+       20.00          NaN
# 7281                           HER2+       16.00          NaN
# 7283           ER+/HER2- High Prolif       30.00          NaN

# %% [markdown]
# ### Cluster Based Analysis

# %% [markdown]
# I will create groupings of individuals based purely on the proteomic data and observe how groupings correlate with death rate.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
protein_data = data[protein_columns]

# %%
knn = KMeans(n_clusters=5)
labels = pd.DataFrame(knn.fit_predict(protein_data), index=protein_data.index, columns=['cluster'])
protein_data_with_label = pd.concat([protein_data, labels], 1)
# pca = PCA(2)
# pca_protein_data = pca.fit_transform(protein_data)
# cluster_data = pd.DataFrame(np.concatenate([pca_protein_data, labels.reshape(-1, 1)], axis=1), columns=['dim_1', 'dim_2', 'label'])

# %%
pca = PCA(3)
pca_protein_data = pca.fit_transform(protein_data)

# %%
pca_protein_data = pd.DataFrame(pca_protein_data)

# %%
pca_protein_data = pd.concat([pca_protein_data, data['overall_survival'].reset_index(drop=True)], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(protein_data, pca_protein_data['overall_survival'], test_size=0.1, stratify=pca_protein_data['overall_survival'])
xgb = XGBClassifier(max_depth=5)
xgb.fit(X_train, y_train)
accuracy_score(xgb.predict(X_test), y_test)
# Out:
# 0.6492146596858639

# %%
most_important_protein_data = protein_data[pd.DataFrame(np.array(list(zip(protein_data.columns, xgb.feature_importances_))), columns=['Feature', 'Importance']).sort_values('Importance', ascending=False)[:10].Feature]

# %%
most_important_protein_data.corr()
# Out:
#           hsd17b11    cdkn2c      jak1      flt3       ran    pdgfra  \
# hsd17b11  1.000000  0.544871  0.595847  0.082348  0.376965  0.558015
# cdkn2c    0.544871  1.000000  0.317715  0.050202  0.262673  0.423631
# jak1      0.595847  0.317715  1.000000  0.097151  0.451033  0.263536
# flt3      0.082348  0.050202  0.097151  1.000000  0.028813 -0.007111
# ran       0.376965  0.262673  0.451033  0.028813  1.000000  0.023845
# pdgfra    0.558015  0.423631  0.263536 -0.007111  0.023845  1.000000
# rbl2      0.274873  0.070852  0.419008  0.094585  0.268818  0.021877
# rheb      0.358131  0.145013  0.417526 -0.084058  0.395886  0.177305
# mmp11    -0.082705 -0.239643 -0.065674 -0.059173 -0.085683  0.099847
# map2k4   -0.035608 -0.080822  0.067554  0.193982  0.091901 -0.186521
#
#               rbl2      rheb     mmp11    map2k4
# hsd17b11  0.274873  0.358131 -0.082705 -0.035608
# cdkn2c    0.070852  0.145013 -0.239643 -0.080822
# jak1      0.419008  0.417526 -0.065674  0.067554
# flt3      0.094585 -0.084058 -0.059173  0.193982
# ran       0.268818  0.395886 -0.085683  0.091901
# pdgfra    0.021877  0.177305  0.099847 -0.186521
# rbl2      1.000000  0.198105 -0.086023  0.060431
# rheb      0.198105  1.000000 -0.012694 -0.101032
# mmp11    -0.086023 -0.012694  1.000000 -0.082347
# map2k4    0.060431 -0.101032 -0.082347  1.000000

# %%
pd.DataFrame(np.array(list(zip(protein_data.columns, xgb.feature_importances_))), columns=['Feature', 'Importance']).sort_values('Importance', ascending=False)[:10]
# Out:
#       Feature    Importance
# 451  hsd17b11    0.01759166
# 437    cdkn2c  0.0070518972
# 47       jak1  0.0064113596
# 344      flt3  0.0060768295
# 471       ran  0.0058708135
# 231    pdgfra  0.0058695585
# 22       rbl2  0.0058545005
# 244      rheb  0.0055888165
# 206     mmp11  0.0053660735
# 187    map2k4  0.0053097056

# %%
def get_death_rate(data):
    return (data['death_from_cancer'] == 'Died of Disease').sum() / data.shape[0]

# %%
data_ = pd.concat([data, pd.DataFrame(labels, columns=['Cluster'], index=data.index)], axis=1)

# %%
data_.Cluster.value_counts()
# Out:
# 1    900
# 0    618
# 2    386
# Name: Cluster, dtype: int64

# %%
data_.groupby('Cluster').apply(get_death_rate)
# Out:
# Cluster
# 0    0.351133
# 1    0.275556
# 2    0.409326
# dtype: float64

# %% [markdown]
# # Building Quick Model For Guidance

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
data = pd.concat([data.dropna(axis=1), data.death_from_cancer], axis=1)

# %%
data = data[data.death_from_cancer.notna()]

# %%
X, y = data.select_dtypes(exclude=['object']).fillna(0).values, data.death_from_cancer.values

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, stratify=y)
y_encoder = LabelEncoder()
y_train = y_encoder.fit_transform(y_train)
y_val = y_encoder.transform(y_val)

# %%
from sklearn.metrics import accuracy_score
xgb = XGBClassifier(max_depth=5)
xgb.fit(X_train, y_train)
accuracy_score(xgb.predict(X_val), y_val)
# Out:
# 0.8115183246073299

# %%
np.array(list(zip(data.select_dtypes(exclude=['object']).columns, xgb.feature_importances_)))
# Out:
# array([['age_at_diagnosis', '0.0077329944'],
#        ['chemotherapy', '0.009456122'],
#        ['cohort', '0.00302665'],
#        ...,
#        ['smarcb1_mut', '0.0'],
#        ['stmn2_mut', '0.0'],
#        ['siah1_mut', '0.0']], dtype='<U29')

# %%
import model_utils as mu

# %%
from importlib import reload

# %%
reload(mu)
# Out:
# <module 'model_utils' from 'C:\\Users\\tjs_1\\OneDrive\\Documents\\Git repos\\Metabric-RNA-Mutation\\model_utils.py'>

# %%
mu.plot_feature_importance(data.select_dtypes(exclude=['object']).columns, xgb.feature_importances_, 50)
